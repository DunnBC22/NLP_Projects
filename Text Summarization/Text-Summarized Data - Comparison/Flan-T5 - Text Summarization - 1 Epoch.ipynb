# %% [markdown]
# ## Text Summarization Using Flan-T5 Transformer Model
#
# Dataset Source: https://www.kaggle.com/datasets/cuitengfeui/textsummarization-data

# %% [markdown]
# #### Install Missing Libraries

# %%
# %pip install sentencepiece rouge-score nltk tensorboard
# Out:
# Requirement already satisfied: sentencepiece in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (0.1.97)
# Requirement already satisfied: rouge-score in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (0.1.2)
# Requirement already satisfied: nltk in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (3.7)
# Requirement already satisfied: tensorboard in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (2.11.0)
# Requirement already satisfied: six>=1.14.0 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: numpy in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from rouge-score) (1.24.2)
# Requirement already satisfied: absl-py in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from rouge-score) (1.2.0)
# Requirement already satisfied: joblib in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: click in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from nltk) (2022.9.13)
# Requirement already satisfied: tqdm in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from tensorboard) (3.20.1)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from tensorboard) (1.51.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from tensorboard) (58.1.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from tensorboard) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from tensorboard) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from tensorboard) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from tensorboard) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from tensorboard) (0.38.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from tensorboard) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from tensorboard) (2.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard) (5.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard) (1.26.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Importing Necessary Libraries

# %%
import os, sys
os.environ['TOKENIZERS_PARALLELISM']='false'

import torch
import torch.nn

import pandas as pd
import numpy as np

from tqdm import tqdm
import nltk

import matplotlib.pyplot as plt

import transformers
from transformers import AutoTokenizer, set_seed, AutoModelForSeq2SeqLM
from transformers import DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer

from datasets import Dataset, DatasetDict, load_dataset

import evaluate

# !git lfs install
# Out:
# Git LFS initialized.

# %% [markdown]
# #### Versions of Some Necessary Libraries Used

# %%
library_Spacing = 20
print("Python:".rjust(library_Spacing), sys.version[0:6])
print("NumPy:".rjust(library_Spacing), np.__version__)
print("Pandas:".rjust(library_Spacing), pd.__version__)
print("Transformers:".rjust(library_Spacing), transformers.__version__)
print("Torch:".rjust(library_Spacing), torch.__version__)
# Out:
#              Python: 3.9.12
#               NumPy: 1.24.2
#              Pandas: 1.5.0
#        Transformers: 4.26.1
#               Torch: 1.12.1

# %% [markdown]
# #### Ingest & Start Preprocessing Training Dataset

# %%
parent_dir = "/Users/briandunn/Desktop/nlp_ds/Text Summarization/text-summarized data"

train_data_file = os.path.join(parent_dir, "train.csv")

train_df = pd.read_csv(train_data_file)

train_df.drop_duplicates(inplace=True)

train_df.dropna(inplace=True)

train_df.rename(columns={"document": "article", "title": "summary"}, inplace=True)

train_df
# Out:
#                                                  article  \
# 0      jason blake of the islanders will miss the res...
# 1      the u.s. military on wednesday captured a wife...
# 2      craig bellamy 's future at west ham appeared i...
# 3      cambridge - when barack obama sought advice be...
# 4      wall street held on to steep gains on monday ,...
# ...                                                  ...
# 19995  a rapidly growing world population and threat ...
# 19996  ahead of nuclear talks between senior iranian ...
# 19997  airbus ceo thomas enders dismissed a french in...
# 19998  albania 's central bank said friday it has iss...
# 19999  south africa 's deputy president phumzile mlam...
#
#                                                  summary
# 0                           blake missing rest of season
# 1      u.s. arrests wife and daughter of saddam deput...
# 2           west ham drops bellamy amid transfer turmoil
# 3            in search for expertise harvard looms large
# 4             wall street ends a three-day losing streak
# ...                                                  ...
# 19995  u.n. food agency must help more people with le...
# 19996  us urges iran to change course on its nuclear ...
# 19997  airbus ceo thomas enders calls eads insider tr...
# 19998                 central bank licenses a local bank
# 19999                s. african deputy president burgled
#
# [19966 rows x 2 columns]

# %% [markdown]
# #### Ingest & Start Preprocessing Evaluation Dataset

# %%
eval_data_file = os.path.join(parent_dir, "val.csv")

eval_df = pd.read_csv(eval_data_file)

eval_df.drop_duplicates(inplace=True)

eval_df.dropna(inplace=True)

eval_df.rename(columns={"document": "article", "title": "summary"}, inplace=True)

eval_df
# Out:
#                                                article  \
# 0    mr. emmons also was part of the design team fo...
# 1    the secret 's out : in `` in &amp; out , '' to...
# 2    indonesia 's top security official said thursd...
# 3    <unk> on the tongue , pungent to the nose , gi...
# 4    thirty years after they were written off as de...
# ..                                                 ...
# 995  `` who wants to die with money in the stock ma...
# 996  the iraqi government 's failure to grasp the s...
# 997  the provisional results of the european parlia...
# 998  british prime minister tony blair saturday wel...
# 999  a small earthquake rocked russia 's buryatia r...
#
#                                                summary
# 0    donn emmons architect of northern california l...
# 1    in &amp; out brings gay sensibilities to mains...
# 2    top security minister suspects foreign terrori...
# 3                                    warm up to ginger
# 4            vietnamese commandos seek payment from us
# ..                                                 ...
# 995            records set for ## contemporary artists
# 996                  iraq far behind in mine clearance
# 997  <unk> to remain biggest party group in europea...
# 998           gore blair agree to boost cyber commerce
# 999               small earthquake reported in siberia
#
# [1000 rows x 2 columns]

# %% [markdown]
# #### Remove Unnecessary Whitespace

# %%
train_df["article"] = train_df["article"].str.strip()
train_df["summary"] = train_df["summary"].str.strip()
eval_df["article"] = eval_df["article"].str.strip()
eval_df["summary"] = eval_df["summary"].str.strip()

# %% [markdown]
# #### Visualize Length of Each Article

# %%
train_df['article_lengths'] = train_df['article'].str.split().apply(len)
eval_df['article_lengths'] = eval_df['article'].str.split().apply(len)

article_lengths = pd.concat([pd.Series(train_df['article_lengths']), pd.Series(eval_df['article_lengths'])])

print(f"The longest string (in words) in this dataset is {max(article_lengths)} words.")

n = 100
article_lengths.hist(grid=True, color="Blue", figsize=(12,5), bins=n, range=(0, n))
plt.suptitle('')
plt.xlabel('Article Length (in Words)')
plt.ylabel('# of Articles w/ That Length')
plt.title('Article Length')
plt.show()
# Out:
# The longest string (in words) in this dataset is 74 words.

# %% [markdown]
# #### Visualize Length of Each Summary

# %%
train_df['summary_lengths'] = train_df['summary'].str.split().apply(len)
eval_df['summary_lengths'] = eval_df['summary'].str.split().apply(len)

summary_lengths = pd.concat([pd.Series(train_df['summary_lengths']), pd.Series(eval_df['summary_lengths'])])

print(f"The longest string (in words) in this dataset is {max(summary_lengths)} words.")

n = 30
summary_lengths.hist(grid=True, color="Blue", figsize=(12,5), bins=n, range=(0, n))
plt.suptitle('')
plt.xlabel('Summary Length (in Words)')
plt.ylabel('# of Articles w/ That Length')
plt.title('Summary Length')
plt.show()
# Out:
# The longest string (in words) in this dataset is 26 words.

# %% [markdown]
# #### Trimmed Dataset Based on Article &/or Summary Length

# %%
# trim training & evaluation article lengths to have no more than 60 words
train_df = train_df[train_df['article_lengths'] < 61]
train_df = train_df[train_df['article_lengths'] > 17]

eval_df = eval_df[eval_df['article_lengths'] < 61]
eval_df = eval_df[eval_df['article_lengths'] > 17]

# trim training & evaluation article lengths to have no less than 18 words
train_df = train_df[train_df['summary_lengths'] < 19]
eval_df = eval_df[eval_df['summary_lengths'] < 19]

train_df.reset_index(drop=True, inplace=True)
eval_df.reset_index(drop=True, inplace=True)

max_article_length = max(max(train_df['article_lengths']), max(eval_df['article_lengths']))
max_summary_length = max(max(train_df['summary_lengths']), max(eval_df['summary_lengths']))

print(f"The longest string (in words) in this dataset is {max_article_length} words.")
print(f"The longest string (in words) in this dataset is {max_summary_length} words.")

# drop unnecessary features
train_df = train_df.drop(columns=['article_lengths', 'summary_lengths'])
eval_df = eval_df.drop(columns=['article_lengths', 'summary_lengths'])

train_df.head()
# Out:
# The longest string (in words) in this dataset is 60 words.
# The longest string (in words) in this dataset is 18 words.
#                                              article  \
# 0  jason blake of the islanders will miss the res...
# 1  the u.s. military on wednesday captured a wife...
# 2  craig bellamy 's future at west ham appeared i...
# 3  cambridge - when barack obama sought advice be...
# 4  wall street held on to steep gains on monday ,...
#
#                                              summary
# 0                       blake missing rest of season
# 1  u.s. arrests wife and daughter of saddam deput...
# 2       west ham drops bellamy amid transfer turmoil
# 3        in search for expertise harvard looms large
# 4         wall street ends a three-day losing streak

# %% [markdown]
# #### Determine Longest Token Lengths

# %%
MODEL_CKPT = "google/flan-t5-base"

tokenizer = AutoTokenizer.from_pretrained(MODEL_CKPT, 
                                             truncation=True, 
                                             padding=True,
                                             batched=True, 
                                             batch_size=None)

train_a_len = [len(tokenizer.encode(a)) for a in train_df["article"]]
train_s_len = [len(tokenizer.encode(a)) for a in train_df["summary"]]

eval_a_len = [len(tokenizer.encode(a)) for a in eval_df["article"]]
eval_s_len = [len(tokenizer.encode(a)) for a in eval_df["summary"]]

max_art_len = max(max(train_a_len), max(eval_a_len))
max_sum_len = max(max(train_s_len), max(eval_s_len))

print(f"The longest article length is {max_art_len} tokens.")
print(f"The longest summary length is {max_sum_len} tokens.")
# Out:
# The longest article length is 153 tokens.
# The longest summary length is 50 tokens.

# %% [markdown]
# #### Convert DataFrame to Dataset & Split into Train & Eval Datasets

# %%
# Convert pandas dataframe to a dataset
train_ds = Dataset.from_pandas(train_df)
eval_ds = Dataset.from_pandas(eval_df)

# Combine the train/test/valid into one datasetdict
dataset = DatasetDict({
    'train' : train_ds,
    'eval' : eval_ds
})

print('Training Data Shape:', dataset['train'].shape)
print('Validation Data Shape:', dataset['eval'].shape)
# Out:
# Training Data Shape: (19150, 2)
# Validation Data Shape: (945, 2)

# %% [markdown]
# #### Define Basic Constants/Values

# %%
MODEL_CKPT = "google/flan-t5-base"
MODEL_NAME = MODEL_CKPT.split("/")[-1] + "-text_summarization_data"

DEVICE = torch.device("cpu")
set_seed(42)

BATCH_SIZE = 16
NUM_OF_EPOCHS = 1

LEARNING_RATE = 2e-5
STRATEGY = "epoch"

MAX_INPUT_LENGTH = max_art_len + 3
MAX_TARGET_LENGTH = max_sum_len + 3

WEIGHT_DECAY = 0.01
REPORTS_TO = "tensorboard"

PREFIX = "summarize: "

# %% [markdown]
# #### Instantiate both Tokenizer and Model

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_CKPT, 
                                             truncation=True, 
                                             padding=True, 
                                             batched=True, 
                                             batch_size=None)

model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_CKPT)

# %% [markdown]
# #### Create Function to Tokenize & Return Necessary Inputs for Batches of Samples

# %%
def convert_examples_to_features(ex_batch, padding="max_length"):
    inputs = [PREFIX + doc for doc in ex_batch["article"]]
    
    input_encodings = tokenizer(inputs, 
                                max_length=MAX_INPUT_LENGTH, 
                                padding="max_length",
                                truncation=True)
    
    with tokenizer.as_target_tokenizer():
        target_encodings = tokenizer(ex_batch['summary'], 
                                     max_length=MAX_TARGET_LENGTH, 
                                     truncation=True,
                                     padding="max_length")
    
    if padding == "max_length":
        target_encodings["input_ids"] = [
            [(l if l != tokenizer.pad_token_id else -100) for l in label] for label in target_encodings["input_ids"]
        ]
    
    return {"input_ids" : input_encodings["input_ids"],
            "attention_mask" : input_encodings["attention_mask"],
            "labels" : target_encodings["input_ids"],}

# %% [markdown]
# #### Apply Above Function to Dataset

# %%
encoded_ds = dataset.map(convert_examples_to_features, batched=True)
encoded_ds.set_format(type="torch", columns=['input_ids', 'labels', 'attention_mask'])
# Out:
# A Jupyter Widget
# /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:3581: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# A Jupyter Widget

# %% [markdown]
# #### Instantiate TrainingArguments

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir=MODEL_NAME,
    num_train_epochs=NUM_OF_EPOCHS,
    learning_rate=LEARNING_RATE,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    weight_decay=WEIGHT_DECAY,
    logging_strategy=STRATEGY,
    evaluation_strategy=STRATEGY,
    logging_first_step=True,
    disable_tqdm=False,
    report_to=REPORTS_TO,
    predict_with_generate=True,
    push_to_hub=True)

# %% [markdown]
# #### Create Function to Computes Metrics

# %%
rouge_metric = evaluate.load("rouge")

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # Replace -100 in the labels as we cannot decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]
    
    result = rouge_metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    # Extract a few results
    result = {key: value * 100 for key, value in result.items()}
    
    # Add mean generated length
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}

# %% [markdown]
# #### Instantiate Data Collator

# %%
seq2seq_data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# %% [markdown]
# #### Instantiate Trainer

# %%
trainer = Seq2SeqTrainer(model=model, 
                  args=training_args,
                  data_collator=seq2seq_data_collator,
                  train_dataset=encoded_ds['train'], 
                  eval_dataset=encoded_ds['eval'], 
                  tokenizer=tokenizer,
                  compute_metrics=compute_metrics)
# Out:
# Cloning https://huggingface.co/DunnBC22/flan-t5-base-text_summarization_data into local empty directory.

# %% [markdown]
# #### Train Model

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, summary. If article, summary are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# /Users/briandunn/Documents/nlpnn/nlp_ml/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 19150
#   Num Epochs = 1
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1197
#   Number of trainable parameters = 247577856
# A Jupyter Widget
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# {'loss': 1.988, 'learning_rate': 1.998329156223893e-05, 'epoch': 0.0}
# Saving model checkpoint to flan-t5-base-text_summarization_data/checkpoint-500
# Configuration saved in flan-t5-base-text_summarization_data/checkpoint-500/config.json
# Configuration saved in flan-t5-base-text_summarization_data/checkpoint-500/generation_config.json
# Model weights saved in flan-t5-base-text_summarization_data/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in flan-t5-base-text_summarization_data/checkpoint-500/tokenizer_config.json
# Special tokens file saved in flan-t5-base-text_summarization_data/checkpoint-500/special_tokens_map.json
# Copy vocab file to flan-t5-base-text_summarization_data/checkpoint-500/spiece.model
# tokenizer config file saved in flan-t5-base-text_summarization_data/tokenizer_config.json
# Special tokens file saved in flan-t5-base-text_summarization_data/special_tokens_map.json
# Copy vocab file to flan-t5-base-text_summarization_data/spiece.model
# Saving model checkpoint to flan-t5-base-text_summarization_data/checkpoint-1000
# Configuration saved in flan-t5-base-text_summarization_data/checkpoint-1000/config.json
# Configuration saved in flan-t5-base-text_summarization_data/checkpoint-1000/generation_config.json
# Model weights saved in flan-t5-base-text_summarization_data/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in flan-t5-base-text_summarization_data/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in flan-t5-base-text_summarization_data/checkpoint-1000/special_tokens_map.json
# Copy vocab file to flan-t5-base-text_summarization_data/checkpoint-1000/spiece.model
# tokenizer config file saved in flan-t5-base-text_summarization_data/tokenizer_config.json
# Special tokens file saved in flan-t5-base-text_summarization_data/special_tokens_map.json
# Copy vocab file to flan-t5-base-text_summarization_data/spiece.model
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, summary. If article, summary are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 16
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
# {'loss': 2.0287, 'learning_rate': 0.0, 'epoch': 1.0}
# A Jupyter Widget
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# {'eval_loss': 1.7385940551757812, 'eval_rouge1': 43.6615, 'eval_rouge2': 20.349, 'eval_rougeL': 40.1032, 'eval_rougeLsum': 40.1589, 'eval_gen_len': 14.6434, 'eval_runtime': 2080.5615, 'eval_samples_per_second': 0.454, 'eval_steps_per_second': 0.029, 'epoch': 1.0}
# {'train_runtime': 74941.3155, 'train_samples_per_second': 0.256, 'train_steps_per_second': 0.016, 'train_loss': 2.028625026283009, 'epoch': 1.0}
# TrainOutput(global_step=1197, training_loss=2.028625026283009, metrics={'train_runtime': 74941.3155, 'train_samples_per_second': 0.256, 'train_steps_per_second': 0.016, 'train_loss': 2.028625026283009, 'epoch': 1.0})

# %% [markdown]
# #### Compute & Print Metrics

# %%
score = trainer.evaluate()
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, summary. If article, summary are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 16
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
# A Jupyter Widget
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }

# %% [markdown]
# #### Print Out Full Rouge Metric Dictionary

# %%
pd.DataFrame(score, index=[f"FLAN-T5"])
# Out:
#          eval_loss  eval_rouge1  eval_rouge2  eval_rougeL  eval_rougeLsum  \
# FLAN-T5   1.738594      43.6615       20.349      40.1032         40.1589
#
#          eval_gen_len  eval_runtime  eval_samples_per_second  \
# FLAN-T5       14.6434     2104.9768                    0.449
#
#          eval_steps_per_second  epoch
# FLAN-T5                  0.029    1.0

# %% [markdown]
# ### Push Fine-Tuned Model to HuggingFace Hub (My Profile)

# %%
trainer.push_to_hub(commit_message="All Dunn!")
# Out:
# Saving model checkpoint to flan-t5-base-text_summarization_data
# Configuration saved in flan-t5-base-text_summarization_data/config.json
# Configuration saved in flan-t5-base-text_summarization_data/generation_config.json
# Model weights saved in flan-t5-base-text_summarization_data/pytorch_model.bin
# tokenizer config file saved in flan-t5-base-text_summarization_data/tokenizer_config.json
# Special tokens file saved in flan-t5-base-text_summarization_data/special_tokens_map.json
# Copy vocab file to flan-t5-base-text_summarization_data/spiece.model
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# remote: Scanning LFS files of refs/heads/main for validity...
# remote: LFS file scan complete.
# To https://huggingface.co/DunnBC22/flan-t5-base-text_summarization_data
#    efba34a..9cb4fde  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files of refs/heads/main for validity...
# remote: LFS file scan complete.
# To https://huggingface.co/DunnBC22/flan-t5-base-text_summarization_data
#    efba34a..9cb4fde  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Sequence-to-sequence Language Modeling', 'type': 'text2text-generation'}, 'metrics': [{'name': 'Rouge1', 'type': 'rouge', 'value': 43.6615}]}
# To https://huggingface.co/DunnBC22/flan-t5-base-text_summarization_data
#    9cb4fde..3684006  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/DunnBC22/flan-t5-base-text_summarization_data
#    9cb4fde..3684006  main -> main
# 'https://huggingface.co/DunnBC22/flan-t5-base-text_summarization_data/commit/9cb4fde1e0096a4b77726c9cadeaefb855a4a78f'

# %% [markdown]
# ### Notes & Other Takeaways From This Project
# ****
# - Because of how well the model worked with tests on small sample sizes, I thought I could get away with only training for a single epoch. While there are no results for this project using multiple epochs, I am confident that the results will improve.
# ****

# %% [markdown]
# ### Citation
# - Model Checkpoint
#     - @misc{https://doi.org/10.48550/arxiv.2210.11416,
#   doi = {10.48550/ARXIV.2210.11416},
#   url = {https://arxiv.org/abs/2210.11416},
#   author = {Chung, Hyung Won and Hou, Le and Longpre, Shayne and Zoph, Barret and Tay, Yi and Fedus, William and Li, Eric and Wang, Xuezhi and Dehghani, Mostafa and Brahma, Siddhartha and Webson, Albert and Gu, Shixiang Shane and Dai, Zhuyun and Suzgun, Mirac and Chen, Xinyun and Chowdhery, Aakanksha and Narang, Sharan and Mishra, Gaurav and Yu, Adams and Zhao, Vincent and Huang, Yanping and Dai, Andrew and Yu, Hongkun and Petrov, Slav and Chi, Ed H. and Dean, Jeff and Devlin, Jacob and Roberts, Adam and Zhou, Denny and Le, Quoc V. and Wei, Jason},
#   keywords = {Machine Learning (cs.LG), Computation and Language (cs.CL), FOS: Computer and information sciences, FOS: Computer and information sciences},
#   title = {Scaling Instruction-Finetuned Language Models},
#   publisher = {arXiv},
#   year = {2022},
#   copyright = {Creative Commons Attribution 4.0 International}
# }
# ****
# - Rouge Metric Citation
#     - @inproceedings{lin-2004-rouge,
#             title = "{ROUGE}: A Package for Automatic Evaluation of Summaries",
#             author = "Lin, Chin-Yew",
#             booktitle = "Text Summarization Branches Out",
#             month = jul,
#             year = "2004",
#             address = "Barcelona, Spain",
#             publisher = "Association for Computational Linguistics",
#             url = "https://www.aclweb.org/anthology/W04-1013",
#             pages = "74--81",
#         }
